# %% [markdown]
# ## A Sample Jupyter Notebook
#
# A Jupyter Notebook is a convenient way to mix explanatory text, Python code, and results all in one sharable document!  This is a "markdown" cell that is used for text.  The next cell is a "code" cell that executes the 'magic' command that inserts the plots into the Notebook.

# %%
# %matplotlib inline

# %% [markdown]
# Next is a code cell that reads in some data and generates a plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style

df = pd.read_excel('food.xlsx')

ax = df.plot.scatter(x='income', y='food_exp',c='DarkBlue')

plt.show()
